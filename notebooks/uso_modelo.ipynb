# %%
import sys
sys.path.append('..')

import mlflow


import tensorflow as tf
from src.modelo_cnn import treinar_modelo_cnn

(x_train, y_train), (x_test, y_test) = tf.keras.datasets.mnist.load_data()

x_train = x_train.reshape(-1, 28, 28, 1) / 255
x_test = x_test.reshape(-1, 28, 28, 1) / 255

mlflow.autolog()

modelo = treinar_modelo_cnn(x_train, y_train)


metricas = modelo.evaluate(x_test, y_test)
previsoes = modelo.predict(x_test)
# Out:
# 2026/09/09 10:29:41 INFO mlflow.tracking.fluent: Autologging successfully enabled for keras.
# 2026/09/09 10:29:41 INFO mlflow.tracking.fluent: Autologging successfully enabled for sklearn.
# 2026/09/09 10:29:41 INFO mlflow.tracking.fluent: Autologging successfully enabled for tensorflow.
# 2026/09/09 10:29:41 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID '7cdf8c2ab41c418ca2ecb2540e9dd9bd', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current tensorflow workflow
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Epoch 1/20
# 1680/1688 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9305 - loss: 0.2297
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.9307 - loss: 0.2293 - val_accuracy: 0.9723 - val_loss: 0.1010
# Epoch 2/20
# 1683/1688 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9743 - loss: 0.0841
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9743 - loss: 0.0839 - val_accuracy: 0.9797 - val_loss: 0.0766
# Epoch 3/20
# 1678/1688 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9812 - loss: 0.0594
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9812 - loss: 0.0595 - val_accuracy: 0.9822 - val_loss: 0.0668
# Epoch 4/20
# 1685/1688 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9853 - loss: 0.0452
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9853 - loss: 0.0451 - val_accuracy: 0.9845 - val_loss: 0.0592
# Epoch 5/20
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9889 - loss: 0.0344 - val_accuracy: 0.9777 - val_loss: 0.0917
# Epoch 6/20
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9918 - loss: 0.0253 - val_accuracy: 0.9852 - val_loss: 0.0595
# Epoch 7/20
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9932 - loss: 0.0204 - val_accuracy: 0.9790 - val_loss: 0.0849
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 2026/09/09 10:30:28 WARNING mlflow.models.model: `artifact_path` is deprecated. Please use `name` instead.
# 2026/09/09 10:32:37 WARNING mlflow.utils.environment: Encountered an unexpected error while inferring pip requirements (model URI: C:\Users\ianlu\AppData\Local\Temp\tmputn_mjiv\model, flavor: tensorflow). Fall back to return ['tensorflow==2.21.0', 'cloudpickle==3.1.2']. Set logging level to DEBUG to see the full traceback.
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9805 - loss: 0.0593
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step

# %%
print("teste")
# Out:
# teste
